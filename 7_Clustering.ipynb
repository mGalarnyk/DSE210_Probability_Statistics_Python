# %% [markdown]
# <h1 align="center"> Worksheet 7 Clustering </h1>
# <h2 align="center"> Michael Galarnyk </h2> <p></p>

# %%
import matplotlib.pyplot as plt
from struct import unpack
# %matplotlib inline
import numpy as np
from scipy.stats import multivariate_normal
from sklearn import datasets

# %% [markdown]
# <h2 align="center">Loading predicate-matrix-continuous.txt </h2> <p></p>

# %%
path = '/Users/mgalarny/Documents/youtube/DSE210_Probability_Statistics_Python/Animals_with_Attributes/'
real_value = 'predicate-matrix-continuous.txt'
from sklearn.cluster import KMeans
count = 0
#full_data = {i:[] for i in xrange(85)}
full_data = []
with open(path+real_value) as f:
    for line in f: 
        full_data.append(line.split())
        count +=1

#KMeans.fit_predict(full_data)

full_data
# Out:
# [['-1.00',
#   '-1.00',
#   '-1.00',
#   '-1.00',
#   '12.34',
#   '0.00',
#   '0.00',
#   '0.00',
#   '16.11',
#   '9.19',
#   '0.00',
#   '38.09',
#   '4.44',
#   '28.55',
#   '38.75',
#   '5.68',
#   '17.07',
#   '39.99',
#   '0.00',
#   '0.00',
#   '67.08',
#   '7.78',
#   '0.00',
#   '60.24',
#   '16.80',
#   '40.59',
#   '29.70',
#   '5.56',
#   '2.47',
#   '0.00',
#   '87.43',
#   '0.00',
#   '8.64',
#   '9.04',
#   '0.00',
#   '9.23',
#   '1.23',
#   '0.00',
#   '54.58',
#   '70.86',
#   '3.33',
#   '33.56',
#   '8.15',
#   '26.14',
#   '0.00',
#   '67.85',
#   '41.19',
#   '7.36',
#   '1.11',
#   '6.94',
#   '62.32',
#   '0.00',
#   '4.44',
#   '0.00',
#   '57.76',
#   '12.63',
#   '33.24',
#   '61.86',
#   '0.00',
#   '0.00',
#   '0.00',
#   '0.00',
#   '22.72',
#   '55.81',
#   '5.90',
#   '0.00',
#   '0.00',
#   '19.88',
#   '54.79',
#   '4.94',
#   '40.97',
#   '0.00',
#   '22.32',
#   '0.00',
#   '57.14',
#   '0.00',
#   '0.00',
#   '1.23',
#   '10.49',
#   '39.24',
# ...

# %% [markdown]
# <h2 align="center"> Loading Animal Names (Classes) </h2> <p></p>

# %%
path = '/Users/mgalarny/Documents/youtube/DSE210_Probability_Statistics_Python/Animals_with_Attributes/'
animal_text = 'classes.txt'

count = 0
animal_names = {i:[] for i in xrange(50)}
with open(path+animal_text) as f:
    for line in f: 
        animal_names[count].append(line.split())
        count +=1
animal_names
# Out:
# {0: [['1', 'antelope']],
#  1: [['2', 'grizzly+bear']],
#  2: [['3', 'killer+whale']],
#  3: [['4', 'beaver']],
#  4: [['5', 'dalmatian']],
#  5: [['6', 'persian+cat']],
#  6: [['7', 'horse']],
#  7: [['8', 'german+shepherd']],
#  8: [['9', 'blue+whale']],
#  9: [['10', 'siamese+cat']],
#  10: [['11', 'skunk']],
#  11: [['12', 'mole']],
#  12: [['13', 'tiger']],
#  13: [['14', 'hippopotamus']],
#  14: [['15', 'leopard']],
#  15: [['16', 'moose']],
#  16: [['17', 'spider+monkey']],
#  17: [['18', 'humpback+whale']],
#  18: [['19', 'elephant']],
#  19: [['20', 'gorilla']],
#  20: [['21', 'ox']],
#  21: [['22', 'fox']],
#  22: [['23', 'sheep']],
#  23: [['24', 'seal']],
#  24: [['25', 'chimpanzee']],
#  25: [['26', 'hamster']],
#  26: [['27', 'squirrel']],
#  27: [['28', 'rhinoceros']],
#  28: [['29', 'rabbit']],
#  29: [['30', 'bat']],
#  30: [['31', 'giraffe']],
#  31: [['32', 'wolf']],
#  32: [['33', 'chihuahua']],
#  33: [['34', 'rat']],
#  34: [['35', 'weasel']],
# ...

# %% [markdown]
# <h2 align="center"> Smoothing through optimizing c value </h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
print "The best c value for me was c =",c_value[np.argmin(error)], "with a error rate of:", error[np.argmin(error)], "%"
# Out:
# The best c value for me was c = 2800 with a error rate of: 4.29 %

# %% [markdown]
# <h2 align="center">Best c value: 2800, error rate: 4.29 </h2> <p></p>

# %%
boolean_list = [i!=j for i,j in zip(max_prob, test_label)]
index_error = [index for index, tf in enumerate(boolean_list) if tf]

# %%
print(__doc__)

from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

np.random.seed(42)

digits = load_digits()
data = scale(digits.data)

n_samples, n_features = data.shape
n_digits = len(np.unique(digits.target))
labels = digits.target
digits['data'].shape[0],digits['data'].shape[1]
# Out:
# Automatically created module for IPython interactive environment
# (1797, 64)

# %%
import pandas as pd 
df = pd.DataFrame(prob)

#[73,80,111,119,151]
df = df[index_error[0:5]]
df
# Out:
#            73           80           111          119          151
# 0 -4223.154046 -4235.493561 -4199.443401 -4189.854853 -4260.851682
# 1 -4189.005693 -4273.461298 -4080.113158 -4329.780832 -4477.407430
# 2 -4174.963632 -4222.829566 -4136.885762 -4149.806770 -4225.156626
# 3 -4175.487143 -4189.215302 -4149.401338 -4187.803792 -4223.117042
# 4 -4169.282148 -4142.716513 -4126.520789 -4172.388706 -4236.338734
# 5 -4203.749964 -4181.570761 -4178.808948 -4215.198234 -4223.095791
# 6 -4276.080889 -4278.602407 -4206.167506 -4228.735221 -4353.941623
# 7 -4111.870000 -4109.935105 -4089.337807 -4177.236776 -4294.949760
# 8 -4138.661136 -4179.540186 -4119.612502 -4156.345474 -4198.322281
# 9 -4117.665855 -4108.843635 -4110.986420 -4149.552638 -4215.944870

# %%
print "predictions: ", max_prob[index_error[0]], max_prob[index_error[1]], max_prob[index_error[2]], max_prob[index_error[3]], max_prob[index_error[4]]
# Out:
# predictions:  7 9 1 9 8

# %% [markdown]
# <h2 align="center"> Actual (correspond to columns). Notice prediction is close to actual </h2>

# %%
df
# Out:
#              9            7            7            2            9
# 0 -4223.154046 -4235.493561 -4199.443401 -4189.854853 -4260.851682
# 1 -4189.005693 -4273.461298 -4080.113158 -4329.780832 -4477.407430
# 2 -4174.963632 -4222.829566 -4136.885762 -4149.806770 -4225.156626
# 3 -4175.487143 -4189.215302 -4149.401338 -4187.803792 -4223.117042
# 4 -4169.282148 -4142.716513 -4126.520789 -4172.388706 -4236.338734
# 5 -4203.749964 -4181.570761 -4178.808948 -4215.198234 -4223.095791
# 6 -4276.080889 -4278.602407 -4206.167506 -4228.735221 -4353.941623
# 7 -4111.870000 -4109.935105 -4089.337807 -4177.236776 -4294.949760
# 8 -4138.661136 -4179.540186 -4119.612502 -4156.345474 -4198.322281
# 9 -4117.665855 -4108.843635 -4110.986420 -4149.552638 -4215.944870

# %%
index_error[0:5]
# Out:
# [73, 80, 111, 119, 151]
